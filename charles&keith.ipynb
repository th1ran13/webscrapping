# %% [markdown]
# <a href="https://colab.research.google.com/github/th1ran13/webscrapping/blob/main/charles%26keith.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import lxml
import openpyxl


url = 'https://www.charleskeith.com/lk/sale'

excel = openpyxl.Workbook()
sheet = excel.active
sheet.title = 'Products'

sheet.append(['Product No' , 'Product Name' , 'Old Price' , 'New Price' , 'Discount'])

try:

  source = requests.get(url)
  #print(source)
  soup = BeautifulSoup(source.content , 'lxml')
  #print(soup)

  products = soup.find_all('div' , class_ = 'product-tile ')
  #print(products)

  for product in products:
    product_name = product.find('div' , class_ = 'pdp-link product_tile-name').a.text.strip()
    #print(product_name)

    product_oldprice = product.find('span' , class_='strike-through list').text
    #print(product_oldprice)

    product_newprice = product.find('span' , class_ = 'sales sales-discount').text.strip()
    #print(product_newprice)

    product_discount = product.find('div' , class_ = 'discount_percentage tile_discount').text
    #print(product_discount)

    product_no = product.find('a' , class_ = 'link product_tile-link recommender_font')['href'].split('/')[-1].split(".")[0].split("_")[0]
    print(product_no)
    sheet.append([product_name , product_oldprice , product_newprice , produc])
except Exception as e: 
  print(e)

excel.save('Charles&Keith.xlsx')

# %%
# Out:
# Miko Gem-Embellished Satin Sandals
#  - green
#
# Linen Slide Sandals
#  - black
#
# Carol Ruched-Toe Bow-Tie Ballerina Flats
#  - chalk
#
# Carol Ruched-Toe Bow-Tie Ballerina Flats
#  - black
#
# Triple Strap Sculptural Heel Mules
#  - cream
#
# Patent Triple Strap Sculptural Heel Mules
#  - light blue
#
# Triple Strap Sculptural Heel Mules
#  - black
#
# Blake Leather Slingback Heeled Sandals
#  - tan
#
# Blake Leather Slingback Heeled Sandals
#  - multi
#
# Double Strap Block Heel Mules
#  - brick
#
# Dionne Striped Bow-Tie Flat Mules
#  - light blue
#
# Ruched Strap Textured Mules
#  - mustard
#
# Stone Embellished Chain-Link Textured Loafer Mules
#  - taupe
#
# Stone Embellished Chain-Link Loafer Mules
#  - black
#
# Padded Square Toe Mules
#  - white
#
# Croc-Effect Chain-Link Square-Toe Pumps
#  - animal print yellow
#
# Amora Heart Cut-Out Ballerina Pumps
#  - pink
#
# Padded Platform Thong Sandals
#  - lime
#
# Antonia Penny Loafers
#  - dark blue
#
# Antonia Heat-Reactive Penny Loafers
#  - black
#
# Drew Tiger-Print Sports Sandals
#  - red
#
# Drew Tiger-Print Sports Sandals
#  - dark blue
#
# Odette Patent Leather Chelsea Platform Boots
#  - cognac
#
# Odette Patent Leather Chelsea Platform Boots
#  - brown
#
# Girls' Tiger Stripes Velcro Sneakers
#  - chalk
#
# Girls' Tiger Stripes Velcro Sneakers
#  - yellow
#
# Girls' Tiger Stripes Sports Sandals
#  - yellow
#
# Double Buckle Strap Slide Sandals
#  - white
#
# Double Buckle Strap Slide Sandals
#  - dark brown
#
# Double Buckle Strap Slide Sandals
#  - black
#
# Etta Velvet Heeled Thong Sandals​
#  - lilac
#
# Etta Velvet Heeled Thong Sandals​
#  - light grey
#
# Etta Velvet Heeled Thong Sandals​
#  - black
#
# Two-Tone Low-Top Sneakers
#  - white
#
# Two-Tone Low-Top Canvas Sneakers
#  - black
#
# Chunky Chain Link Ankle Boots
#  - black
#
# Chunky Chain Link Ankle Boots
#  - multi
#
# Collette Sculptural Heel Platform Oxfords
#  - military green
#
# Collette Sculptural Heel Platform Oxfords
#  - black
#
# Square Toe Buckled Slide Sandals
#  - white
#
# Metallic Accent Felt Mary Jane Ballerina Flats
#  - grey
#
# Houndstooth-Print Bow-Tie Block Heel Pumps
#  - multi
#
# Collette Sculptural Heel Ankle Boots
#  - military green
#
# Claudette Ruched Velvet Top Handle Bag
#  - sage green
#
# Claudette Ruched Top Handle Bag​
#  - black
#
# Evelynn Push-Lock Shoulder Bag
#  - light grey
#
# Evelynn Push-Lock Textured Shoulder Bag
#  - multi
#
# Evelynn Push-Lock Shoulder Bag
#  - dark oak
#
# Abby Chain Handle Braided Hobo Bag
#  - red
#
# Abby Chain Handle Braided Hobo Bag
#  - navy
#
# Willow Twist Top Handle Shoulder Bag
#  - sage green
#
# Willow Twist Top Handle Shoulder Bag
#  - dark oak
#
# Haisley Penny Loafer Calf Boots
#  - white
#
# Haisley Penny Loafer Calf Boots
#  - pink
#
# Enya Ruched Turn-Lock Shoulder Bag
#  - navy
#
# Chantria Velvet AirPods Pouch
#  - grey
#
# Studded Blade Heel Slingback Sandals
#  - light blue
#
# Leather Pearl-Embellished Slingback Pumps
#  - black
#
# Slip-On Flat Ankle Boots
#  - taupe
#
# Slip-On Flat Ankle Boots
#  - black
